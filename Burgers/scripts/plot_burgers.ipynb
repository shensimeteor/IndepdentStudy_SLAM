# %%
#!/usr/bin/env python
import numpy as np
import matplotlib.pyplot as plt
file="../burgers_run_periodBC.bin"
nx=1000
N=2501
Xs=np.fromfile(file, dtype="double", count=-1).reshape(N,nx)

# %%
#print(Xs)
plot_dt=100

xcoord=np.arange(0,nx)
for i in range(0,N,plot_dt):
    print(i)
    plt.figure()
    Xs[i][Xs[i][:]>100]=np.nan
    plt.plot(xcoord, Xs[i][:], '-o')
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# /home/si/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# /home/si/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py:522: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
